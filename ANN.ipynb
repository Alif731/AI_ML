# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Loading Dataset

# %%
data = pd.read_csv('/content/mobile_price_classification.csv')

# %% [markdown]
# EDA

# %%
data.head()
# Out:
#    battery_power  bluetooth  clock_speed  dual_sim  front_cam  4G  int_memory  \
# 0            842          0          2.2         0          1   0           7
# 1           1021          1          0.5         1          0   1          53
# 2            563          1          0.5         1          2   1          41
# 3            615          1          2.5         0          0   0          10
# 4           1821          1          1.2         0         13   1          44
#
#    m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.6        188        2  ...         20       756  2549     9     7
# 1    0.7        136        3  ...        905      1988  2631    17     3
# 2    0.9        145        5  ...       1263      1716  2603    11     2
# 3    0.8        131        6  ...       1216      1786  2769    16     8
# 4    0.6        141        2  ...       1208      1212  1411     8     2
#
#    talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
data.shape
# Out:
# (2000, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   battery_power   2000 non-null   int64
#  1   bluetooth       2000 non-null   int64
#  2   clock_speed     2000 non-null   float64
#  3   dual_sim        2000 non-null   int64
#  4   front_cam       2000 non-null   int64
#  5   4G              2000 non-null   int64
#  6   int_memory      2000 non-null   int64
#  7   m_dep           2000 non-null   float64
#  8   mobile_wt       2000 non-null   int64
#  9   n_cores         2000 non-null   int64
#  10  primary_camera  2000 non-null   int64
#  11  px_height       2000 non-null   int64
#  12  px_width        2000 non-null   int64
#  13  ram             2000 non-null   int64
#  14  sc_h            2000 non-null   int64
#  15  sc_w            2000 non-null   int64
#  16  talk_time       2000 non-null   int64
# ...

# %%
data.describe()
# Out:
#        battery_power  bluetooth  clock_speed     dual_sim    front_cam  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#                 4G   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
data['price_range'].unique()
# Out:
# array([1, 2, 3, 0])

# %%
data['price_range'].value_counts()
# Out:
# 1    500
# 2    500
# 3    500
# 0    500
# Name: price_range, dtype: int64

# %%
data.columns
# Out:
# Index(['battery_power', 'bluetooth', 'clock_speed', 'dual_sim', 'front_cam',
#        '4G', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'primary_camera',
#        'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
# Assigning Features and Target

x=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
x.head()
# Out:
#    battery_power  bluetooth  clock_speed  dual_sim  front_cam  4G  int_memory  \
# 0            842          0          2.2         0          1   0           7
# 1           1021          1          0.5         1          0   1          53
# 2            563          1          0.5         1          2   1          41
# 3            615          1          2.5         0          0   0          10
# 4           1821          1          1.2         0         13   1          44
#
#    m_dep  mobile_wt  n_cores  primary_camera  px_height  px_width   ram  sc_h  \
# 0    0.6        188        2               2         20       756  2549     9
# 1    0.7        136        3               6        905      1988  2631    17
# 2    0.9        145        5               6       1263      1716  2603    11
# 3    0.8        131        6               9       1216      1786  2769    16
# 4    0.6        141        2              14       1208      1212  1411     8
#
# ...

# %% [markdown]
# Splitting dataset

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
#four categories of price_range to class
from tensorflow.keras.utils import to_categorical
y_train_cat = to_categorical(y_train, num_classes=4)
y_test_cat = to_categorical(y_test, num_classes=4)

# %%
# Model
model = Sequential()
model.add(Dense(20, activation='relu', input_shape=(20,)))
model.add(Dense(10, activation='relu'))
model.add(Dense(7, activation='relu'))
model.add(Dense(4, activation='softmax'))

# %%
# Compiling Model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Fitting the model
history = model.fit(x_train, y_train_cat, validation_data=(x_test, y_test_cat), epochs=200, batch_size=32,verbose=0)

# %%
# Predicting with model
y_pred = model.predict(x_test)
y_pred
# Out:
# 13/13 [==============================] - 0s 2ms/step
# array([[9.99928296e-01, 7.15941133e-05, 9.43575947e-13, 5.39729481e-24],
#        [1.17741520e-05, 2.10672811e-01, 7.53518164e-01, 3.57971266e-02],
#        [7.78886350e-03, 9.91764128e-01, 4.46954218e-04, 9.60323661e-12],
#        ...,
#        [2.55578803e-03, 7.44171977e-01, 2.51981199e-01, 1.29100948e-03],
#        [3.40265105e-04, 7.63928235e-01, 2.35248730e-01, 4.82755975e-04],
#        [6.90247077e-07, 6.30402863e-02, 8.16573381e-01, 1.20385565e-01]],
#       dtype=float32)

# %%
predicted = np.argmax(y_pred, axis=1)
actual_val = pd.DataFrame(list(zip(y_test,predicted)))

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(predicted, y_test)
accuracy
# Out:
# 0.8875

# %% [markdown]
# **Hyperparameter Tuning**

# %%
def create_model(optimizer='adam', activation='relu'):
    model = Sequential()
    model.add(Dense(20, activation=activation, input_shape=(20,)))
    model.add(Dense(10, activation=activation))
    model.add(Dense(7, activation=activation))
    model.add(Dense(4, activation='softmax'))
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# !pip install scikeras
from scikeras.wrappers import KerasClassifier

# %%
# Creating a KerasClassifier
model = KerasClassifier(model=create_model, verbose=0)

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Defining the grid search parameters
param_grid = {
    'batch_size': [16, 32],
    'epochs': [100, 200],
    'model__optimizer': ['adam', 'rmsprop','Adamax', 'Nadam'],
    'model__activation': ['relu', 'tanh']
             }

param_grid
# Out:
# {'batch_size': [16, 32],
#  'epochs': [100, 200],
#  'model__optimizer': ['adam', 'rmsprop', 'Adamax', 'Nadam'],
#  'model__activation': ['relu', 'tanh']}

# %%
#Grid Search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(x_train, y_train_cat)

# %%
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.770558 using {'batch_size': 16, 'epochs': 200, 'model__activation': 'relu', 'model__optimizer': 'adam'}
